# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

with open('intents.json') as file:
    data = json.load(file)

training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for patter in intent['patterns']:
        training_sentences.append(patter)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])

    if intent['tag'] not in labels:
        labels.append(intent['tag'])

num_classes = len(labels)

lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)


vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words = vocab_size, oov_token = oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen = max_len)


model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length = max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(num_classes, activation= 'softmax'))

model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_3 (Embedding)     (None, 20, 16)            16000
#
#  global_average_pooling1d_2  (None, 16)                0
#   (GlobalAveragePooling1D)
#
#  dense_6 (Dense)             (None, 16)                272
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 8)                 136
#
# ...
# Total params: 16680 (65.16 KB)
# Trainable params: 16680 (65.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 1000
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 1s 9ms/step - loss: 2.0785 - accuracy: 0.1515
# Epoch 2/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 2.0775 - accuracy: 0.1515
# Epoch 3/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0773 - accuracy: 0.1515
# Epoch 4/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0771 - accuracy: 0.1515
# Epoch 5/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 2.0767 - accuracy: 0.1515
# Epoch 6/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0762 - accuracy: 0.1515
# Epoch 7/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0757 - accuracy: 0.1515
# Epoch 8/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0752 - accuracy: 0.1515
# Epoch 9/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0748 - accuracy: 0.1515
# Epoch 10/1000
# ...

# %%
# to save the trained model
model.save('chat_model')

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle. HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model\assets
# INFO:tensorflow:Assets written to: chat_model\assets

# %%
# Function to get response from the chatbot
def get_response(user_input):
    # Tokenize and pad the user input
    user_sequence = tokenizer.texts_to_sequences([user_input])
    user_padded_sequence = pad_sequences(user_sequence, truncating='post', maxlen=max_len)

    # Predict the intent using the trained model
    predicted_intent = model.predict_classes(user_padded_sequence)[0]
    predicted_tag = lbl_encoder.inverse_transform([predicted_intent])[0]

    # Check if the predicted intent is a goodbye
    if predicted_tag.lower() == 'goodbye':
        return "Goodbye! Have a great day."
    else:
        # Retrieve a random response for the predicted intent
        response_options = data['intents'][predicted_intent]['responses']
        return np.random.choice(response_options)

# Example of using the chatbot
user_input = input("User: ")
while user_input.lower() not in ['bye', 'goodbye']:
    response = get_response(user_input)
    print("Bot:", response)
    user_input = input("User: ")

print("Bot: Goodbye! Exiting the chatbot.")
# Out:
# User: goodbye
# Bot: Goodbye! Exiting the chatbot.
